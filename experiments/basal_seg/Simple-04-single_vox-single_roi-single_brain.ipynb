# %%
# %matplotlib inline

import os
while 'source' not in os.listdir():
    os.chdir('..')
os.chdir('source')

FORCE = False

# %%
from util import getHashId


props={
    'path'          : 'data',
    'seed'          : 42,
    'split'         : 0.8,
    'test_split'    : 0.5,
    'control'       : True,
    'huntington'    : False,
    'left'          : True,
    'right'         : False,
    'threshold'     : None,
    'binarize'      : False,
    'not_connected' : False,
    'single'        : None,
    'features'      : [],
    'features_vox'  : [],
    #'radiomics'     : ['b10','b25','b50','b75'],
    #'radiomics_vox' : ['k5_b25','k7_b25','k9_b25','k11_b25'],
    'radiomics'     : [
        {'sp':'native','im':'t1','fe':['b25'],'fi':['roi','t1_mask']},
    ],
    'space'         : 'native',
    'radiomics_vox' : [
        {'im':'t1','fe':['k5_b25']},
    ],
    'rad_vox_norm'  : 'norm',
    'outp'          : 'basal_seg',
    'balance_data'  : True,
    'targets_all'   : False,
    'collapse_max'  : False,
    'debug'         : False,
}

architecture={
    'activation'    : 'sigmoid',
    'layers'        : [1024,512,256,128],
    'loss'          : 'CCE',
    'learning_rate' : 0.001,
    'batch_size'    : 100000,
    'patience'      : 10,
}

HASHID, HASH = getHashId(architecture,props)
print(HASH)
# Out:
# sigmoid_100000_1024_512_256_128_0001_CCE_10_1_0_0_1_0_e_e_0_1_0_basal_seg_data_norm_b25_roi_t1_mask_t1_native_k5_b25_t1_0_42_n_native_08_0_05_n

# %%
from DataGeneratorClassificationFNN import DataGenerator

gen = DataGenerator(**props)
train, val, test = gen.getData()

print('train')
print(train[0].shape)
print(train[1].shape)
print('validation')
print(val[0].shape)
print(val[1].shape)
print('test')
print(test[0].shape)
print(test[1].shape)
# Out:
# train
# (878801, 304)
# (878801, 3)
# validation
# (151459, 304)
# (151459, 3)
# test
# (112754, 304)
# (112754, 3)

# %%
from ModelClassificationFNN import *
from tensorflow.keras.optimizers import Adam

path = props['path']+'/models'

stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=architecture['patience'],
)
save = tf.keras.callbacks.ModelCheckpoint(
    filepath=path+'/{}.weights.h5'.format(HASHID),
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    save_weights_only=True,
)

model = buildModel(train[0].shape[1], train[1].shape[1], activation=architecture['activation'], layers=architecture['layers'])

model.compile(loss=locals()[architecture['loss']], optimizer=Adam(learning_rate=architecture['learning_rate']), jit_compile=True, metrics=[STD,MAE])

model.summary()
# Out:
# Model: "FFN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 304)]             0
#
#  dense (Dense)               (None, 1024)              312320
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dense_4 (Dense)             (None, 3)                 387
#
# =================================================================
# Total params: 1001731 (3.82 MB)
# Trainable params: 1001731 (3.82 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import os
from util import pickleSave

if FORCE or not os.path.exists(path+'/{}.pkl'.format(HASHID)):
    history = model.fit(DataWrapper(train,architecture['batch_size']),
        validation_data=DataWrapper(val,architecture['batch_size'],False),
        epochs=10000,
        verbose=1,
        callbacks = [save,stop],
    )
    pickleSave(path+'/{}.pkl'.format(HASHID), history.history)

model.load_weights(path+'/{}.weights.h5'.format(HASHID))
# Out:
# Epoch 1/10000
# 9/9 [==============================] - 15s 956ms/step - loss: 1.1743 - STD: 0.1548 - MAE: 0.4300 - val_loss: 1.0839 - val_STD: 0.0881 - val_MAE: 0.4340
# Epoch 2/10000
# 9/9 [==============================] - 3s 272ms/step - loss: 1.0898 - STD: 0.0374 - MAE: 0.4405 - val_loss: 1.0734 - val_STD: 0.0839 - val_MAE: 0.4320
# Epoch 3/10000
# 9/9 [==============================] - 2s 261ms/step - loss: 1.0795 - STD: 0.1043 - MAE: 0.4290 - val_loss: 1.0724 - val_STD: 0.0784 - val_MAE: 0.4327
# Epoch 4/10000
# 9/9 [==============================] - 2s 266ms/step - loss: 1.0740 - STD: 0.0548 - MAE: 0.4360 - val_loss: 1.0709 - val_STD: 0.0647 - val_MAE: 0.4343
# Epoch 5/10000
# 9/9 [==============================] - 2s 255ms/step - loss: 1.0704 - STD: 0.0821 - MAE: 0.4314 - val_loss: 1.0671 - val_STD: 0.0792 - val_MAE: 0.4312
# Epoch 6/10000
# 9/9 [==============================] - 2s 253ms/step - loss: 1.0640 - STD: 0.0672 - MAE: 0.4321 - val_loss: 1.0564 - val_STD: 0.0683 - val_MAE: 0.4301
# Epoch 7/10000
# 9/9 [==============================] - 3s 268ms/step - loss: 1.0446 - STD: 0.0786 - MAE: 0.4254 - val_loss: 1.0220 - val_STD: 0.0846 - val_MAE: 0.4186
# Epoch 8/10000
# 9/9 [==============================] - 3s 277ms/step - loss: 0.9918 - STD: 0.1032 - MAE: 0.4073 - val_loss: 0.9559 - val_STD: 0.1474 - val_MAE: 0.3876
# Epoch 9/10000
# 9/9 [==============================] - 2s 264ms/step - loss: 0.9341 - STD: 0.1767 - MAE: 0.3735 - val_loss: 0.9219 - val_STD: 0.1992 - val_MAE: 0.3630
# Epoch 10/10000
# 9/9 [==============================] - 2s 262ms/step - loss: 0.8980 - STD: 0.1939 - MAE: 0.3604 - val_loss: 0.8917 - val_STD: 0.2072 - val_MAE: 0.3534
# Epoch 11/10000
# 9/9 [==============================] - 2s 255ms/step - loss: 0.8702 - STD: 0.2083 - MAE: 0.3487 - val_loss: 0.8752 - val_STD: 0.2140 - val_MAE: 0.3466
# Epoch 12/10000
# 9/9 [==============================] - 2s 261ms/step - loss: 0.8518 - STD: 0.2184 - MAE: 0.3406 - val_loss: 0.8552 - val_STD: 0.2278 - val_MAE: 0.3365
# Epoch 13/10000
# 9/9 [==============================] - 2s 258ms/step - loss: 0.8387 - STD: 0.2281 - MAE: 0.3337 - val_loss: 0.8432 - val_STD: 0.2452 - val_MAE: 0.3257
# Epoch 14/10000
# 9/9 [==============================] - 2s 260ms/step - loss: 0.8297 - STD: 0.2352 - MAE: 0.3287 - val_loss: 0.8376 - val_STD: 0.2581 - val_MAE: 0.3185
# Epoch 15/10000
# 9/9 [==============================] - 2s 268ms/step - loss: 0.8261 - STD: 0.2413 - MAE: 0.3253 - val_loss: 0.8301 - val_STD: 0.2502 - val_MAE: 0.3211
# Epoch 16/10000
# 9/9 [==============================] - 2s 243ms/step - loss: 0.8191 - STD: 0.2430 - MAE: 0.3232 - val_loss: 0.8262 - val_STD: 0.2593 - val_MAE: 0.3160
# Epoch 17/10000
# 9/9 [==============================] - 2s 246ms/step - loss: 0.8143 - STD: 0.2457 - MAE: 0.3210 - val_loss: 0.8226 - val_STD: 0.2624 - val_MAE: 0.3138
# Epoch 18/10000
# 9/9 [==============================] - 2s 224ms/step - loss: 0.8074 - STD: 0.2494 - MAE: 0.3178 - val_loss: 0.8163 - val_STD: 0.2601 - val_MAE: 0.3137
# Epoch 19/10000
# 9/9 [==============================] - 2s 231ms/step - loss: 0.7994 - STD: 0.2517 - MAE: 0.3150 - val_loss: 0.8096 - val_STD: 0.2652 - val_MAE: 0.3098
# Epoch 20/10000
# 9/9 [==============================] - 2s 252ms/step - loss: 0.7919 - STD: 0.2563 - MAE: 0.3110 - val_loss: 0.8055 - val_STD: 0.2678 - val_MAE: 0.3077
# Epoch 21/10000
# 9/9 [==============================] - 2s 268ms/step - loss: 0.7851 - STD: 0.2597 - MAE: 0.3078 - val_loss: 0.8051 - val_STD: 0.2732 - val_MAE: 0.3046
# Epoch 22/10000
# 9/9 [==============================] - 2s 224ms/step - loss: 0.7812 - STD: 0.2620 - MAE: 0.3057 - val_loss: 0.8012 - val_STD: 0.2775 - val_MAE: 0.3016
# Epoch 23/10000
# 9/9 [==============================] - 2s 233ms/step - loss: 0.7768 - STD: 0.2638 - MAE: 0.3038 - val_loss: 0.7978 - val_STD: 0.2783 - val_MAE: 0.3004
# Epoch 24/10000
# 9/9 [==============================] - 2s 212ms/step - loss: 0.7730 - STD: 0.2654 - MAE: 0.3022 - val_loss: 0.7956 - val_STD: 0.2825 - val_MAE: 0.2977
# Epoch 25/10000
# 9/9 [==============================] - 2s 235ms/step - loss: 0.7698 - STD: 0.2667 - MAE: 0.3010 - val_loss: 0.7982 - val_STD: 0.2797 - val_MAE: 0.2994
# Epoch 26/10000
# 9/9 [==============================] - 2s 270ms/step - loss: 0.7665 - STD: 0.2674 - MAE: 0.2999 - val_loss: 0.7901 - val_STD: 0.2864 - val_MAE: 0.2946
# Epoch 27/10000
# 9/9 [==============================] - 2s 236ms/step - loss: 0.7622 - STD: 0.2692 - MAE: 0.2982 - val_loss: 0.7865 - val_STD: 0.2843 - val_MAE: 0.2949
# Epoch 28/10000
# 9/9 [==============================] - 2s 241ms/step - loss: 0.7585 - STD: 0.2707 - MAE: 0.2967 - val_loss: 0.7841 - val_STD: 0.2856 - val_MAE: 0.2937
# Epoch 29/10000
# 9/9 [==============================] - 2s 252ms/step - loss: 0.7551 - STD: 0.2719 - MAE: 0.2954 - val_loss: 0.7780 - val_STD: 0.2868 - val_MAE: 0.2922
# Epoch 30/10000
# 9/9 [==============================] - 2s 269ms/step - loss: 0.7526 - STD: 0.2727 - MAE: 0.2945 - val_loss: 0.7761 - val_STD: 0.2918 - val_MAE: 0.2892
# Epoch 31/10000
# 9/9 [==============================] - 2s 276ms/step - loss: 0.7483 - STD: 0.2737 - MAE: 0.2932 - val_loss: 0.7714 - val_STD: 0.2902 - val_MAE: 0.2890
# Epoch 32/10000
# 9/9 [==============================] - 2s 254ms/step - loss: 0.7432 - STD: 0.2750 - MAE: 0.2915 - val_loss: 0.7734 - val_STD: 0.2934 - val_MAE: 0.2873
# Epoch 33/10000
# 9/9 [==============================] - 2s 250ms/step - loss: 0.7501 - STD: 0.2776 - MAE: 0.2916 - val_loss: 0.7726 - val_STD: 0.2951 - val_MAE: 0.2871
# Epoch 34/10000
# 9/9 [==============================] - 3s 273ms/step - loss: 0.7423 - STD: 0.2753 - MAE: 0.2913 - val_loss: 0.7653 - val_STD: 0.2933 - val_MAE: 0.2863
# Epoch 35/10000
# 9/9 [==============================] - 3s 268ms/step - loss: 0.7376 - STD: 0.2770 - MAE: 0.2894 - val_loss: 0.7630 - val_STD: 0.2941 - val_MAE: 0.2852
# Epoch 36/10000
# 9/9 [==============================] - 2s 248ms/step - loss: 0.7347 - STD: 0.2790 - MAE: 0.2877 - val_loss: 0.7644 - val_STD: 0.2961 - val_MAE: 0.2840
# Epoch 37/10000
# 9/9 [==============================] - 2s 266ms/step - loss: 0.7321 - STD: 0.2801 - MAE: 0.2866 - val_loss: 0.7594 - val_STD: 0.2984 - val_MAE: 0.2820
# Epoch 38/10000
# 9/9 [==============================] - 2s 246ms/step - loss: 0.7306 - STD: 0.2807 - MAE: 0.2860 - val_loss: 0.7613 - val_STD: 0.3010 - val_MAE: 0.2805
# Epoch 39/10000
# 9/9 [==============================] - 2s 255ms/step - loss: 0.7290 - STD: 0.2816 - MAE: 0.2852 - val_loss: 0.7728 - val_STD: 0.3053 - val_MAE: 0.2796
# Epoch 40/10000
# 9/9 [==============================] - 2s 250ms/step - loss: 0.7287 - STD: 0.2826 - MAE: 0.2845 - val_loss: 0.7655 - val_STD: 0.3030 - val_MAE: 0.2797
# Epoch 41/10000
# 9/9 [==============================] - 2s 261ms/step - loss: 0.7249 - STD: 0.2830 - MAE: 0.2836 - val_loss: 0.7534 - val_STD: 0.3006 - val_MAE: 0.2796
# Epoch 42/10000
# 9/9 [==============================] - 2s 243ms/step - loss: 0.7243 - STD: 0.2836 - MAE: 0.2831 - val_loss: 0.7564 - val_STD: 0.3038 - val_MAE: 0.2777
# Epoch 43/10000
# 9/9 [==============================] - 2s 247ms/step - loss: 0.7218 - STD: 0.2840 - MAE: 0.2824 - val_loss: 0.7517 - val_STD: 0.3039 - val_MAE: 0.2773
# Epoch 44/10000
# 9/9 [==============================] - 2s 238ms/step - loss: 0.7254 - STD: 0.2858 - MAE: 0.2821 - val_loss: 0.7550 - val_STD: 0.3061 - val_MAE: 0.2761
# Epoch 45/10000
# 9/9 [==============================] - 2s 253ms/step - loss: 0.7217 - STD: 0.2846 - MAE: 0.2820 - val_loss: 0.7535 - val_STD: 0.3081 - val_MAE: 0.2754
# Epoch 46/10000
# 9/9 [==============================] - 2s 259ms/step - loss: 0.7195 - STD: 0.2849 - MAE: 0.2815 - val_loss: 0.7548 - val_STD: 0.3061 - val_MAE: 0.2759
# Epoch 47/10000
# 9/9 [==============================] - 2s 260ms/step - loss: 0.7201 - STD: 0.2867 - MAE: 0.2805 - val_loss: 0.7595 - val_STD: 0.3052 - val_MAE: 0.2772
# Epoch 48/10000
# 9/9 [==============================] - 3s 276ms/step - loss: 0.7199 - STD: 0.2860 - MAE: 0.2809 - val_loss: 0.7509 - val_STD: 0.3073 - val_MAE: 0.2754
# Epoch 49/10000
# 9/9 [==============================] - 2s 241ms/step - loss: 0.7194 - STD: 0.2859 - MAE: 0.2808 - val_loss: 0.7471 - val_STD: 0.3047 - val_MAE: 0.2757
# Epoch 50/10000
# 9/9 [==============================] - 2s 243ms/step - loss: 0.7168 - STD: 0.2862 - MAE: 0.2802 - val_loss: 0.7497 - val_STD: 0.3022 - val_MAE: 0.2775
# Epoch 51/10000
# 9/9 [==============================] - 2s 253ms/step - loss: 0.7149 - STD: 0.2874 - MAE: 0.2791 - val_loss: 0.7477 - val_STD: 0.3038 - val_MAE: 0.2763
# Epoch 52/10000
# 9/9 [==============================] - 2s 253ms/step - loss: 0.7123 - STD: 0.2872 - MAE: 0.2787 - val_loss: 0.7503 - val_STD: 0.3083 - val_MAE: 0.2737
# Epoch 53/10000
# 9/9 [==============================] - 3s 264ms/step - loss: 0.7129 - STD: 0.2884 - MAE: 0.2781 - val_loss: 0.7541 - val_STD: 0.3089 - val_MAE: 0.2739
# Epoch 54/10000
# 9/9 [==============================] - 3s 274ms/step - loss: 0.7124 - STD: 0.2886 - MAE: 0.2779 - val_loss: 0.7449 - val_STD: 0.3090 - val_MAE: 0.2726
# Epoch 55/10000
# 9/9 [==============================] - 2s 238ms/step - loss: 0.7110 - STD: 0.2885 - MAE: 0.2776 - val_loss: 0.7465 - val_STD: 0.3101 - val_MAE: 0.2729
# Epoch 56/10000
# 9/9 [==============================] - 2s 243ms/step - loss: 0.7113 - STD: 0.2891 - MAE: 0.2773 - val_loss: 0.7446 - val_STD: 0.3094 - val_MAE: 0.2722
# Epoch 57/10000
# 9/9 [==============================] - 2s 250ms/step - loss: 0.7086 - STD: 0.2890 - MAE: 0.2768 - val_loss: 0.7540 - val_STD: 0.3088 - val_MAE: 0.2738
# Epoch 58/10000
# 9/9 [==============================] - 2s 222ms/step - loss: 0.7106 - STD: 0.2897 - MAE: 0.2768 - val_loss: 0.7428 - val_STD: 0.3095 - val_MAE: 0.2719
# Epoch 59/10000
# 9/9 [==============================] - 2s 227ms/step - loss: 0.7082 - STD: 0.2896 - MAE: 0.2764 - val_loss: 0.7432 - val_STD: 0.3112 - val_MAE: 0.2715
# Epoch 60/10000
# 9/9 [==============================] - 2s 257ms/step - loss: 0.7076 - STD: 0.2900 - MAE: 0.2761 - val_loss: 0.7463 - val_STD: 0.3098 - val_MAE: 0.2720
# Epoch 61/10000
# 9/9 [==============================] - 2s 228ms/step - loss: 0.7051 - STD: 0.2899 - MAE: 0.2756 - val_loss: 0.7417 - val_STD: 0.3093 - val_MAE: 0.2718
# Epoch 62/10000
# 9/9 [==============================] - 2s 255ms/step - loss: 0.7035 - STD: 0.2906 - MAE: 0.2749 - val_loss: 0.7399 - val_STD: 0.3099 - val_MAE: 0.2712
# Epoch 63/10000
# 9/9 [==============================] - 2s 240ms/step - loss: 0.7046 - STD: 0.2911 - MAE: 0.2749 - val_loss: 0.7474 - val_STD: 0.3144 - val_MAE: 0.2705
# Epoch 64/10000
# 9/9 [==============================] - 2s 261ms/step - loss: 0.7078 - STD: 0.2916 - MAE: 0.2752 - val_loss: 0.7408 - val_STD: 0.3136 - val_MAE: 0.2694
# Epoch 65/10000
# 9/9 [==============================] - 3s 279ms/step - loss: 0.7032 - STD: 0.2909 - MAE: 0.2746 - val_loss: 0.7394 - val_STD: 0.3128 - val_MAE: 0.2695
# Epoch 66/10000
# 9/9 [==============================] - 3s 265ms/step - loss: 0.7018 - STD: 0.2910 - MAE: 0.2744 - val_loss: 0.7431 - val_STD: 0.3101 - val_MAE: 0.2713
# Epoch 67/10000
# 9/9 [==============================] - 2s 250ms/step - loss: 0.7078 - STD: 0.2924 - MAE: 0.2746 - val_loss: 0.7470 - val_STD: 0.3114 - val_MAE: 0.2710
# Epoch 68/10000
# 9/9 [==============================] - 3s 267ms/step - loss: 0.7010 - STD: 0.2910 - MAE: 0.2741 - val_loss: 0.7386 - val_STD: 0.3132 - val_MAE: 0.2691
# Epoch 69/10000
# 9/9 [==============================] - 3s 264ms/step - loss: 0.6988 - STD: 0.2915 - MAE: 0.2734 - val_loss: 0.7378 - val_STD: 0.3133 - val_MAE: 0.2687
# Epoch 70/10000
# 9/9 [==============================] - 3s 275ms/step - loss: 0.6984 - STD: 0.2926 - MAE: 0.2727 - val_loss: 0.7423 - val_STD: 0.3139 - val_MAE: 0.2687
# Epoch 71/10000
# 9/9 [==============================] - 2s 248ms/step - loss: 0.7046 - STD: 0.2938 - MAE: 0.2732 - val_loss: 0.7417 - val_STD: 0.3125 - val_MAE: 0.2695
# Epoch 72/10000
# 9/9 [==============================] - 2s 237ms/step - loss: 0.6988 - STD: 0.2920 - MAE: 0.2731 - val_loss: 0.7421 - val_STD: 0.3129 - val_MAE: 0.2693
# Epoch 73/10000
# 9/9 [==============================] - 2s 258ms/step - loss: 0.6975 - STD: 0.2927 - MAE: 0.2724 - val_loss: 0.7376 - val_STD: 0.3131 - val_MAE: 0.2687
# Epoch 74/10000
# 9/9 [==============================] - 2s 247ms/step - loss: 0.6958 - STD: 0.2929 - MAE: 0.2719 - val_loss: 0.7394 - val_STD: 0.3143 - val_MAE: 0.2680
# Epoch 75/10000
# 9/9 [==============================] - 2s 253ms/step - loss: 0.7065 - STD: 0.2949 - MAE: 0.2729 - val_loss: 0.7419 - val_STD: 0.3134 - val_MAE: 0.2689
# Epoch 76/10000
# 9/9 [==============================] - 3s 283ms/step - loss: 0.6975 - STD: 0.2923 - MAE: 0.2726 - val_loss: 0.7366 - val_STD: 0.3101 - val_MAE: 0.2705
# Epoch 77/10000
# 9/9 [==============================] - 2s 259ms/step - loss: 0.6960 - STD: 0.2922 - MAE: 0.2724 - val_loss: 0.7375 - val_STD: 0.3172 - val_MAE: 0.2663
# Epoch 78/10000
# 9/9 [==============================] - 2s 258ms/step - loss: 0.6950 - STD: 0.2939 - MAE: 0.2712 - val_loss: 0.7354 - val_STD: 0.3104 - val_MAE: 0.2702
# Epoch 79/10000
# 9/9 [==============================] - 2s 268ms/step - loss: 0.6948 - STD: 0.2935 - MAE: 0.2714 - val_loss: 0.7352 - val_STD: 0.3159 - val_MAE: 0.2667
# Epoch 80/10000
# 9/9 [==============================] - 2s 259ms/step - loss: 0.6951 - STD: 0.2947 - MAE: 0.2708 - val_loss: 0.7347 - val_STD: 0.3153 - val_MAE: 0.2670
# Epoch 81/10000
# 9/9 [==============================] - 2s 248ms/step - loss: 0.6976 - STD: 0.2943 - MAE: 0.2716 - val_loss: 0.7347 - val_STD: 0.3145 - val_MAE: 0.2677
# Epoch 82/10000
# 9/9 [==============================] - 2s 258ms/step - loss: 0.6978 - STD: 0.2939 - MAE: 0.2718 - val_loss: 0.7410 - val_STD: 0.3189 - val_MAE: 0.2665
# Epoch 83/10000
# 9/9 [==============================] - 2s 259ms/step - loss: 0.6943 - STD: 0.2944 - MAE: 0.2709 - val_loss: 0.7358 - val_STD: 0.3141 - val_MAE: 0.2677
# Epoch 84/10000
# 9/9 [==============================] - 2s 244ms/step - loss: 0.6919 - STD: 0.2940 - MAE: 0.2705 - val_loss: 0.7419 - val_STD: 0.3123 - val_MAE: 0.2695
# Epoch 85/10000
# 9/9 [==============================] - 2s 260ms/step - loss: 0.6936 - STD: 0.2951 - MAE: 0.2702 - val_loss: 0.7375 - val_STD: 0.3155 - val_MAE: 0.2669
# Epoch 86/10000
# 9/9 [==============================] - 2s 254ms/step - loss: 0.6912 - STD: 0.2949 - MAE: 0.2698 - val_loss: 0.7344 - val_STD: 0.3139 - val_MAE: 0.2675
# Epoch 87/10000
# 9/9 [==============================] - 2s 254ms/step - loss: 0.6892 - STD: 0.2949 - MAE: 0.2694 - val_loss: 0.7350 - val_STD: 0.3189 - val_MAE: 0.2649
# Epoch 88/10000
# 9/9 [==============================] - 2s 255ms/step - loss: 0.6925 - STD: 0.2956 - MAE: 0.2697 - val_loss: 0.7365 - val_STD: 0.3133 - val_MAE: 0.2680
# Epoch 89/10000
# 9/9 [==============================] - 2s 262ms/step - loss: 0.6902 - STD: 0.2950 - MAE: 0.2696 - val_loss: 0.7375 - val_STD: 0.3199 - val_MAE: 0.2644
# Epoch 90/10000
# 9/9 [==============================] - 3s 267ms/step - loss: 0.6976 - STD: 0.2971 - MAE: 0.2698 - val_loss: 0.7381 - val_STD: 0.3138 - val_MAE: 0.2691
# Epoch 91/10000
# 9/9 [==============================] - 3s 302ms/step - loss: 0.6937 - STD: 0.2953 - MAE: 0.2701 - val_loss: 0.7334 - val_STD: 0.3121 - val_MAE: 0.2685
# Epoch 92/10000
# 9/9 [==============================] - 3s 268ms/step - loss: 0.6880 - STD: 0.2942 - MAE: 0.2696 - val_loss: 0.7337 - val_STD: 0.3178 - val_MAE: 0.2653
# Epoch 93/10000
# 9/9 [==============================] - 3s 279ms/step - loss: 0.6873 - STD: 0.2953 - MAE: 0.2688 - val_loss: 0.7326 - val_STD: 0.3153 - val_MAE: 0.2664
# Epoch 94/10000
# 9/9 [==============================] - 3s 270ms/step - loss: 0.6873 - STD: 0.2963 - MAE: 0.2682 - val_loss: 0.7314 - val_STD: 0.3160 - val_MAE: 0.2657
# Epoch 95/10000
# 9/9 [==============================] - 2s 263ms/step - loss: 0.6872 - STD: 0.2969 - MAE: 0.2678 - val_loss: 0.7442 - val_STD: 0.3146 - val_MAE: 0.2682
# Epoch 96/10000
# 9/9 [==============================] - 3s 268ms/step - loss: 0.6926 - STD: 0.2970 - MAE: 0.2689 - val_loss: 0.7384 - val_STD: 0.3143 - val_MAE: 0.2676
# Epoch 97/10000
# 9/9 [==============================] - 3s 268ms/step - loss: 0.6876 - STD: 0.2957 - MAE: 0.2686 - val_loss: 0.7343 - val_STD: 0.3170 - val_MAE: 0.2655
# Epoch 98/10000
# 9/9 [==============================] - 2s 249ms/step - loss: 0.6849 - STD: 0.2962 - MAE: 0.2677 - val_loss: 0.7340 - val_STD: 0.3147 - val_MAE: 0.2667
# Epoch 99/10000
# 9/9 [==============================] - 2s 265ms/step - loss: 0.6840 - STD: 0.2963 - MAE: 0.2675 - val_loss: 0.7345 - val_STD: 0.3192 - val_MAE: 0.2641
# Epoch 100/10000
# 9/9 [==============================] - 3s 283ms/step - loss: 0.6835 - STD: 0.2973 - MAE: 0.2669 - val_loss: 0.7352 - val_STD: 0.3159 - val_MAE: 0.2660
# Epoch 101/10000
# 9/9 [==============================] - 2s 248ms/step - loss: 0.6917 - STD: 0.2986 - MAE: 0.2677 - val_loss: 0.7319 - val_STD: 0.3155 - val_MAE: 0.2661
# Epoch 102/10000
# 9/9 [==============================] - 2s 254ms/step - loss: 0.6847 - STD: 0.2966 - MAE: 0.2675 - val_loss: 0.7331 - val_STD: 0.3150 - val_MAE: 0.2664
# Epoch 103/10000
# 9/9 [==============================] - 3s 271ms/step - loss: 0.6837 - STD: 0.2966 - MAE: 0.2673 - val_loss: 0.7352 - val_STD: 0.3191 - val_MAE: 0.2643
# Epoch 104/10000
# 9/9 [==============================] - 3s 286ms/step - loss: 0.6830 - STD: 0.2971 - MAE: 0.2669 - val_loss: 0.7301 - val_STD: 0.3187 - val_MAE: 0.2640
# Epoch 105/10000
# 9/9 [==============================] - 2s 264ms/step - loss: 0.6816 - STD: 0.2979 - MAE: 0.2661 - val_loss: 0.7318 - val_STD: 0.3140 - val_MAE: 0.2670
# Epoch 106/10000
# 9/9 [==============================] - 3s 275ms/step - loss: 0.6810 - STD: 0.2976 - MAE: 0.2662 - val_loss: 0.7314 - val_STD: 0.3153 - val_MAE: 0.2659
# Epoch 107/10000
# 9/9 [==============================] - 2s 245ms/step - loss: 0.6940 - STD: 0.2998 - MAE: 0.2674 - val_loss: 0.7384 - val_STD: 0.3112 - val_MAE: 0.2702
# Epoch 108/10000
# 9/9 [==============================] - 2s 250ms/step - loss: 0.6871 - STD: 0.2962 - MAE: 0.2682 - val_loss: 0.7327 - val_STD: 0.3177 - val_MAE: 0.2649
# Epoch 109/10000
# 9/9 [==============================] - 2s 241ms/step - loss: 0.6812 - STD: 0.2973 - MAE: 0.2664 - val_loss: 0.7275 - val_STD: 0.3135 - val_MAE: 0.2666
# Epoch 110/10000
# 9/9 [==============================] - 2s 209ms/step - loss: 0.6784 - STD: 0.2970 - MAE: 0.2660 - val_loss: 0.7303 - val_STD: 0.3167 - val_MAE: 0.2653
# Epoch 111/10000
# 9/9 [==============================] - 2s 222ms/step - loss: 0.6797 - STD: 0.2980 - MAE: 0.2657 - val_loss: 0.7335 - val_STD: 0.3220 - val_MAE: 0.2627
# Epoch 112/10000
# 9/9 [==============================] - 2s 239ms/step - loss: 0.6808 - STD: 0.2988 - MAE: 0.2654 - val_loss: 0.7364 - val_STD: 0.3171 - val_MAE: 0.2666
# Epoch 113/10000
# 9/9 [==============================] - 2s 190ms/step - loss: 0.6835 - STD: 0.2996 - MAE: 0.2654 - val_loss: 0.7361 - val_STD: 0.3174 - val_MAE: 0.2652
# Epoch 114/10000
# 9/9 [==============================] - 2s 224ms/step - loss: 0.6806 - STD: 0.2987 - MAE: 0.2654 - val_loss: 0.7304 - val_STD: 0.3157 - val_MAE: 0.2659
# Epoch 115/10000
# 9/9 [==============================] - 2s 216ms/step - loss: 0.6766 - STD: 0.2976 - MAE: 0.2653 - val_loss: 0.7301 - val_STD: 0.3195 - val_MAE: 0.2636
# Epoch 116/10000
# 9/9 [==============================] - 2s 212ms/step - loss: 0.6748 - STD: 0.2991 - MAE: 0.2640 - val_loss: 0.7273 - val_STD: 0.3162 - val_MAE: 0.2650
# Epoch 117/10000
# 9/9 [==============================] - 2s 186ms/step - loss: 0.6771 - STD: 0.2996 - MAE: 0.2641 - val_loss: 0.7362 - val_STD: 0.3215 - val_MAE: 0.2636
# Epoch 118/10000
# 9/9 [==============================] - 2s 176ms/step - loss: 0.6749 - STD: 0.3000 - MAE: 0.2634 - val_loss: 0.7325 - val_STD: 0.3216 - val_MAE: 0.2626
# Epoch 119/10000
# 9/9 [==============================] - 2s 222ms/step - loss: 0.6731 - STD: 0.2998 - MAE: 0.2632 - val_loss: 0.7296 - val_STD: 0.3198 - val_MAE: 0.2628
# Epoch 120/10000
# 9/9 [==============================] - 2s 217ms/step - loss: 0.6784 - STD: 0.3004 - MAE: 0.2641 - val_loss: 0.7297 - val_STD: 0.3184 - val_MAE: 0.2636
# Epoch 121/10000
# 9/9 [==============================] - 2s 204ms/step - loss: 0.6750 - STD: 0.3001 - MAE: 0.2635 - val_loss: 0.7577 - val_STD: 0.3298 - val_MAE: 0.2620
# Epoch 122/10000
# 9/9 [==============================] - 2s 195ms/step - loss: 0.6888 - STD: 0.3009 - MAE: 0.2657 - val_loss: 0.7326 - val_STD: 0.3124 - val_MAE: 0.2680
# Epoch 123/10000
# 9/9 [==============================] - 2s 190ms/step - loss: 0.6744 - STD: 0.2975 - MAE: 0.2648 - val_loss: 0.7325 - val_STD: 0.3214 - val_MAE: 0.2628
# Epoch 124/10000
# 9/9 [==============================] - 2s 165ms/step - loss: 0.6713 - STD: 0.2996 - MAE: 0.2630 - val_loss: 0.7284 - val_STD: 0.3174 - val_MAE: 0.2643
# Epoch 125/10000
# 9/9 [==============================] - 2s 231ms/step - loss: 0.6704 - STD: 0.3008 - MAE: 0.2621 - val_loss: 0.7366 - val_STD: 0.3212 - val_MAE: 0.2637
# Epoch 126/10000
# 9/9 [==============================] - 2s 235ms/step - loss: 0.6751 - STD: 0.3019 - MAE: 0.2622 - val_loss: 0.7290 - val_STD: 0.3191 - val_MAE: 0.2635

# %%
from util import pickleLoad
from visual import plotHistory

history = pickleLoad(path+'/{}.pkl'.format(HASHID))
plotHistory(history)

# %%
from util import getAccuarcy, predictInBatches

print('balanced')
print(getAccuarcy(train[1],predictInBatches(model,train[0],architecture['batch_size'])))
print(getAccuarcy(val[1],predictInBatches(model,val[0],architecture['batch_size'])))
print(getAccuarcy(test[1],predictInBatches(model,test[0],architecture['batch_size'])))
# Out:
# balanced
# 0.7109209024568702
# 0.6823298714503595
# 0.6856519502634053

# %%
props2 = props.copy()
props2['balance_data'] = False
gen2 = DataGenerator(**props2)
train2, val2, test2 = gen2.getData()

print('original')
print(getAccuarcy(train2[1],predictInBatches(model,train2[0],architecture['batch_size'])))
print(getAccuarcy(val2[1],predictInBatches(model,val2[0],architecture['batch_size'])))
print(getAccuarcy(test2[1],predictInBatches(model,test2[0],architecture['batch_size'])))
# Out:
# original
# 0.7305736033387081
# 0.6986821494245046
# 0.713030645421634

# %%
showResults(model, gen, threshold=0)
