# %%
# %matplotlib inline

import os
while 'source' not in os.listdir():
    os.chdir('..')
os.chdir('source')

FORCE = False

# %%
from util import getHashId


props={
    'path'          : 'data',
    'seed'          : 42,
    'split'         : 0.8,
    'test_split'    : 0.5,
    'control'       : True,
    'huntington'    : False,
    'left'          : True,
    'right'         : False,
    'threshold'     : 0.6,
    'binarize'      : True,
    'not_connected' : True,
    'single'        : None,
    'features'      : [],
    'features_vox'  : [],
    #'radiomics'     : ['b10','b25','b50','b75'],
    #'radiomics_vox' : ['k5_b25','k7_b25','k9_b25','k11_b25'],
    'radiomics'     : [
        {'sp':'normalized','im':'t1','fe':['b25'],'fi':['roi']},
    ],
    'space'         : 'normalized',
    'radiomics_vox' : [
        {'im':'t1','fe':['k5_b25','k7_b25','k9_b25','k11_b25','k13_b25']},
    ],
    'rad_vox_norm'  : 'norm',
    'outp'          : 'connectivity',
    'balance_data'  : True,
    'targets_all'   : False,
    'collapse_max'  : False,
    'debug'         : False,
}

architecture={
    'activation'    : 'sigmoid',
    'layers'        : [2048,1024,512,256,128],
    'loss'          : 'CCE',
    'learning_rate' : 0.001,
    'batch_size'    : 100000,
    'patience'      : 7,
}

HASHID, HASH = getHashId(architecture,props)
print(HASH)
# Out:
# sigmoid_100000_2048_1024_512_256_128_0001_CCE_7_1_1_0_1_0_e_e_0_1_1_connectivity_data_norm_b25_roi_t1_normalized_k5_b25_k7_b25_k9_b25_k11_b25_k13_b25_t1_0_42_n_normalized_08_0_05_06

# %%
from DataGenerator import DataGenerator

gen = DataGenerator(**props)
train, val, test = gen.getData()

print('train')
print(train[0].shape)
print(train[1].shape)
print('validation')
print(val[0].shape)
print(val[1].shape)
print('test')
print(test[0].shape)
print(test[1].shape)
# Out:
# train
# (2390920, 552)
# (2390920, 8)
# validation
# (359320, 552)
# (359320, 8)
# test
# (307352, 552)
# (307352, 8)

# %%
from Model import *
from tensorflow.keras.optimizers import Adam

path = props['path']+'/models'

stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=architecture['patience'],
)
save = tf.keras.callbacks.ModelCheckpoint(
    filepath=path+'/{}.weights.h5'.format(HASHID),
    monitor='val_loss',
    mode='min',
    save_best_only=True,
    save_weights_only=True,
)

model = buildModel(train[0].shape[1], train[1].shape[1], activation=architecture['activation'], layers=architecture['layers'])

model.compile(loss=locals()[architecture['loss']], optimizer=Adam(learning_rate=architecture['learning_rate']), jit_compile=True, metrics=[STD,MAE])

model.summary()
# Out:
# Model: "FFN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 552)]             0
#
#  dense (Dense)               (None, 2048)              1132544
#
#  dense_1 (Dense)             (None, 1024)              2098176
#
#  dense_2 (Dense)             (None, 512)               524800
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dense_5 (Dense)             (None, 8)                 1032
#
# =================================================================
# Total params: 3920776 (14.96 MB)
# Trainable params: 3920776 (14.96 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import os
from util import pickleSave

if FORCE or not os.path.exists(path+'/{}.pkl'.format(HASHID)):
    history = model.fit(DataWrapper(train,architecture['batch_size']),
        validation_data=DataWrapper(val,architecture['batch_size'],False),
        epochs=10000,
        verbose=1,
        callbacks = [save,stop],
    )
    pickleSave(path+'/{}.pkl'.format(HASHID), history.history)

model.load_weights(path+'/{}.weights.h5'.format(HASHID))
# Out:
# Epoch 1/10000
# 24/24 [==============================] - 32s 887ms/step - loss: 2.0664 - STD: 0.0369 - MAE: 0.2167 - val_loss: 2.0528 - val_STD: 0.0311 - val_MAE: 0.2168
# Epoch 2/10000
# 24/24 [==============================] - 11s 428ms/step - loss: 2.0470 - STD: 0.0323 - MAE: 0.2165 - val_loss: 2.0183 - val_STD: 0.0342 - val_MAE: 0.2155
# Epoch 3/10000
# 24/24 [==============================] - 10s 421ms/step - loss: 1.9087 - STD: 0.0638 - MAE: 0.2093 - val_loss: 1.8394 - val_STD: 0.0824 - val_MAE: 0.2054
# Epoch 4/10000
# 24/24 [==============================] - 11s 441ms/step - loss: 1.7951 - STD: 0.0859 - MAE: 0.2033 - val_loss: 1.7236 - val_STD: 0.0937 - val_MAE: 0.2003
# Epoch 5/10000
# 24/24 [==============================] - 11s 432ms/step - loss: 1.7277 - STD: 0.0956 - MAE: 0.1997 - val_loss: 1.6906 - val_STD: 0.1035 - val_MAE: 0.1977
# Epoch 6/10000
# 24/24 [==============================] - 11s 448ms/step - loss: 1.6763 - STD: 0.1031 - MAE: 0.1965 - val_loss: 1.6166 - val_STD: 0.1080 - val_MAE: 0.1938
# Epoch 7/10000
# 24/24 [==============================] - 11s 450ms/step - loss: 1.6273 - STD: 0.1119 - MAE: 0.1922 - val_loss: 1.5517 - val_STD: 0.1233 - val_MAE: 0.1868
# Epoch 8/10000
# 24/24 [==============================] - 11s 457ms/step - loss: 1.5766 - STD: 0.1253 - MAE: 0.1868 - val_loss: 1.5309 - val_STD: 0.1275 - val_MAE: 0.1849
# Epoch 9/10000
# 24/24 [==============================] - 11s 449ms/step - loss: 1.5360 - STD: 0.1298 - MAE: 0.1839 - val_loss: 1.4898 - val_STD: 0.1350 - val_MAE: 0.1807
# Epoch 10/10000
# 24/24 [==============================] - 11s 449ms/step - loss: 1.5024 - STD: 0.1365 - MAE: 0.1805 - val_loss: 1.4205 - val_STD: 0.1441 - val_MAE: 0.1751
# Epoch 11/10000
# 24/24 [==============================] - 10s 421ms/step - loss: 1.4665 - STD: 0.1413 - MAE: 0.1775 - val_loss: 1.4246 - val_STD: 0.1440 - val_MAE: 0.1750
# Epoch 12/10000
# 24/24 [==============================] - 11s 436ms/step - loss: 1.4397 - STD: 0.1463 - MAE: 0.1748 - val_loss: 1.3561 - val_STD: 0.1485 - val_MAE: 0.1705
# Epoch 13/10000
# 24/24 [==============================] - 11s 442ms/step - loss: 1.4216 - STD: 0.1495 - MAE: 0.1730 - val_loss: 1.3556 - val_STD: 0.1513 - val_MAE: 0.1698
# Epoch 14/10000
# 24/24 [==============================] - 11s 435ms/step - loss: 1.4067 - STD: 0.1519 - MAE: 0.1716 - val_loss: 1.3349 - val_STD: 0.1560 - val_MAE: 0.1674
# Epoch 15/10000
# 24/24 [==============================] - 10s 418ms/step - loss: 1.3823 - STD: 0.1554 - MAE: 0.1695 - val_loss: 1.4107 - val_STD: 0.1646 - val_MAE: 0.1683
# Epoch 16/10000
# 24/24 [==============================] - 10s 410ms/step - loss: 1.3794 - STD: 0.1556 - MAE: 0.1693 - val_loss: 1.3281 - val_STD: 0.1581 - val_MAE: 0.1666
# Epoch 17/10000
# 24/24 [==============================] - 10s 401ms/step - loss: 1.3647 - STD: 0.1577 - MAE: 0.1681 - val_loss: 1.3389 - val_STD: 0.1599 - val_MAE: 0.1669
# Epoch 18/10000
# 24/24 [==============================] - 10s 406ms/step - loss: 1.3381 - STD: 0.1598 - MAE: 0.1661 - val_loss: 1.3389 - val_STD: 0.1636 - val_MAE: 0.1656
# Epoch 19/10000
# 24/24 [==============================] - 10s 422ms/step - loss: 1.3439 - STD: 0.1604 - MAE: 0.1663 - val_loss: 1.3385 - val_STD: 0.1678 - val_MAE: 0.1643
# Epoch 20/10000
# 24/24 [==============================] - 10s 399ms/step - loss: 1.3237 - STD: 0.1637 - MAE: 0.1643 - val_loss: 1.3643 - val_STD: 0.1705 - val_MAE: 0.1644
# Epoch 21/10000
# 24/24 [==============================] - 11s 432ms/step - loss: 1.3063 - STD: 0.1642 - MAE: 0.1633 - val_loss: 1.3605 - val_STD: 0.1743 - val_MAE: 0.1628
# Epoch 22/10000
# 24/24 [==============================] - 10s 415ms/step - loss: 1.3040 - STD: 0.1667 - MAE: 0.1623 - val_loss: 1.4783 - val_STD: 0.1805 - val_MAE: 0.1646
# Epoch 23/10000
# 24/24 [==============================] - 11s 428ms/step - loss: 1.3197 - STD: 0.1650 - MAE: 0.1637 - val_loss: 1.3429 - val_STD: 0.1738 - val_MAE: 0.1620

# %%
from util import pickleLoad
from visual import plotHistory

history = pickleLoad(path+'/{}.pkl'.format(HASHID))
plotHistory(history)

# %%
from util import getAccuarcy, predictInBatches

print('balanced')
print(getAccuarcy(train[1],predictInBatches(model,train[0],architecture['batch_size'])))
print(getAccuarcy(val[1],predictInBatches(model,val[0],architecture['batch_size'])))
print(getAccuarcy(test[1],predictInBatches(model,test[0],architecture['batch_size'])))
# Out:
# balanced
# 0.461020025764141
# 0.46765557163531113
# 0.41978578307608216

# %%
props2 = props.copy()
props2['balance_data'] = False
gen2 = DataGenerator(**props2)
train2, val2, test2 = gen2.getData()

print('original')
print(getAccuarcy(train2[1],predictInBatches(model,train2[0],architecture['batch_size'])))
print(getAccuarcy(val2[1],predictInBatches(model,val2[0],architecture['batch_size'])))
print(getAccuarcy(test2[1],predictInBatches(model,test2[0],architecture['batch_size'])))
# Out:
# original
# 0.4186143026742057
# 0.4171792049721611
# 0.3654007313728478

# %%
showResults(model, gen, threshold=0)
